# %% [markdown]
# #  Data Analysis of IPL-Matches(2008-2022)
# As you all know Cricket is a sport played and watched by millions of people around the world but Indians are mad about cricket. Cricket is played in our streets. We like it so much. People in india are crazy about the game. Cricket is a Gentlemen Game , As a cricket lover, I decided to analyze the data of IPL matches. Why IPL match? Because cricket is not a game of any specific country or a nation, I love Indian league IPL .So, that why I shall anlyze the data of IPL matches from 2008 to 2022.
#
# - I found IPL matches (2008-2022) dataset from kaggle.
# - Here is the link of IPL matches Dataset: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv

# %% [markdown]
# ## Data Selection and Installing
# First we will select appropriate dataset from kaggle which I have done. You can check it at this link: https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv. To download our dataset we have to install open dataset library by pip install command.

# %% [markdown]
# ## Essential Libraries for this Project
# Lets import essential libraries for this project

# %%
! pip .install matplotlib
# Out:
# Access is denied.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = "#00000000"

# %%
import warnings  # to ignore the warnings so that will 
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Analising IPL Match Dataset

# %% [markdown]
# ## Data Preparation and Cleaning
# First, we load our dataset into DataFrame and see our DataFrame some first and last rows to overview of dataset

# %%
df = pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %% [markdown]
# By looking at the dataset we can see that our dataset contains many rows and columns. The dataset includes **MatchNumber**, **Team1**, **Team2**, **Venue**, **Team1Players**, **Team2Players**, **Umpire1** and **Umpire2** Data which gives us information about where match held, which teams played a match and about team players, about umpires also and information about **winning team** and win stats.

# %%
df.shape
# Out:
# (950, 20)

# %% [markdown]
# There is 950 rows and 20 columns in our Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# cols with conatins null value
# City, SuperOver  ,WinningTeam ,Margin  ,method  ,Player_of_Match

# %%
df.describe()['Margin']
# Out:
# count    932.000000
# mean      17.056867
# std       21.633109
# min        1.000000
# 25%        6.000000
# 50%        8.000000
# 75%       19.000000
# max      146.000000
# Name: Margin, dtype: float64

# %% [markdown]
# > I cant say about mean,median and other statistical values >
# depended on wonby col(runs,wickets,superover,)

# %%
df['WonBy'].value_counts()
# Out:
# WonBy
# Wickets      509
# Runs         423
# SuperOver     14
# NoResults      4
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               18
# Team2               18
# Venue               49
# TossWinner          18
# TossDecision         2
# SuperOver            2
# WinningTeam         18
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %% [markdown]
# #### The above table provides us with very useful information. By above table we can see that as of 2022, there have been 15 seasons of IPL tournament hosted by 33 cities. Although, 18 teams have played and 262 Players become player of match in past seasons of IPL.

# %%
print("Total Null Cells"),df.isnull().sum().sum()
df.isnull().sum()
# Out:
# Total Null Cells
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df['Date'].dtype # date and  time dtype
# Out:
# dtype('O')

# %% [markdown]
# in our DataFrame the date should be a string that represent date for future work with date. Let's convert all cells in **Date** column to dates. Pandas have **datetime()** method for this.

# %%
pd.to_datetime(df['Date'])
df.Date.head(5)
# Out:
# 0    2022-05-29
# 1    2022-05-27
# 2    2022-05-25
# 3    2022-05-24
# 4    2022-05-22
# Name: Date, dtype: object

# %%
df['Date'].dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# Now, we will clean empty cells, wrong data and unusual data. We will also check any duplicate data in our dataset.

# %%
# checking with duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# > Thre are no duplicates within the dataset

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df['City'].value_counts().sort_index()
# Out:
# City
# Abu Dhabi          37
# Ahmedabad          19
# Bangalore          65
# Bengaluru          15
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         56
# Chennai            67
# Cuttack             7
# Delhi              78
# Dharamsala          9
# Dubai              13
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            79
# Mumbai            159
# Nagpur              3
# Navi Mumbai         9
# Port Elizabeth      7
# Pune               51
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah            10
# Visakhapatnam      13
# Name: count, dtype: int64

# %%
df['City']=df['City'].replace('Bengluru','Banglore')

# %%
df['City'].replace('Bengluru','Banglore')
# Out:
# 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object

# %%
df['City'].value_counts().sort_index()
# Out:
# City
# Abu Dhabi          37
# Ahmedabad          19
# Bangalore          65
# Bengaluru          15
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         56
# Chennai            67
# Cuttack             7
# Delhi              78
# Dharamsala          9
# Dubai              13
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            79
# Mumbai            159
# Nagpur              3
# Navi Mumbai         9
# Port Elizabeth      7
# Pune               51
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah            10
# Visakhapatnam      13
# Name: count, dtype: int64

# %% [markdown]
# In IPL there are some teams whose named changed after some season. So, we will also rename the teams to get more efficient analysis.

# %%
df['Team1'].str.replace('Kings XI Punjab','Punjab','Punjab Kings')
df['Team2'].str.replace('Kings XI Punjab','Punjab Kings')
df['WinningTeam'].str.replace('Kings XI Punjab','Punjab Kings')
# Out:
# 0                   Gujarat Titans
# 1                 Rajasthan Royals
# 2      Royal Challengers Bangalore
# 3                   Gujarat Titans
# 4                     Punjab Kings
#                   ...
# 945          Kolkata Knight Riders
# 946    Royal Challengers Bangalore
# 947               Delhi Daredevils
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Name: WinningTeam, Length: 950, dtype: object

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df['Team1']=df['Team2'].replace('King XI Punjab','punjab Kings')

# %%
df['Team1'].value_counts()
# Out:
# Team1
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Delhi Daredevils                76
# Deccan Chargers                 36
# Delhi Capitals                  34
# Pune Warriors                   23
# Gujarat Lions                   14
# Punjab Kings                    10
# Gujarat Titans                   9
# Rising Pune Supergiant           9
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df['Team2']=df['Team2'].replace('King XI Punjab','punjab Kings')

# %%
df['WinningTeam']=df['WinningTeam'].replace('King XI Punjab','punjab Kings')

# %%
df['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Gujarat Titans                  12
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df['TossWinner']=df['TossWinner'].replace('King XI Punjab','punjab Kings')

# %%
df['TossWinner'].value_counts()
# Out:
# TossWinner
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Punjab Kings                     9
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
df['Team1']=df['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
df['Team2']=df['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')
df['WinningTeam']=df['WinningTeam'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
df.TossWinner.value_counts()
# Out:
# TossWinner
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Punjab Kings                     9
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
df['Team1']=df['Team1'].replace('Rising Pune Supergiants','Rising Pune Supergiant')
df['Team2']=df['Team2'].replace('Rising Pune Supergiants','Rising Pune Supergiant')
df['WinningTeam']=df['WinningTeam'].replace('Rising Pune Supergiants','Rising Pune Supergiant')

# %%
df.WinningTeam.value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Delhi Capitals                 103
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Deccan Chargers                 29
# Rising Pune Supergiant          15
# Punjab Kings                    13
# Gujarat Lions                   13
# Pune Warriors                   12
# Gujarat Titans                  12
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Name: count, dtype: int64

# %% [markdown]
# dealing with null values

# %%
df.isnull().value_counts().sum()
# Out:
# np.int64(950)

# %%
# city 
c1=df['City'].isnull()
df[c1]['Venue'].value_counts()
#-----
# Out:
# Venue
# Dubai International Cricket Stadium    33
# Sharjah Cricket Stadium                18
# Name: count, dtype: int64

# %%
vf1 = (df['Venue'] == 'Sharjah Cricket Stadium')
df.loc[vf1,'City'] = 'Sharjah'

# %%
vf1 = (df['Venue'] == 'Sharjah Cricket Stadium')
df.loc[vf1,'City'] = 'Sharjah'

# %%
vf1 = (df['Venue'] == 'Dubai International Cricket Stadium ')
df.loc[vf1,'City'] = 'Dubai'

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                33
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df['SuperOver'].fillna('NoResult',inplace=True)
df['WinningTeam'].fillna('NoResult',inplace=True)
df['Player_of_Match'].fillna('NoResult',inplace= True)
df['Margin'].fillna('NoMargin',inplace = True)

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                33
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            0
# WinningTeam          0
# WonBy                0
# Margin               0
# method             931
# Player_of_Match      0
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.drop(columns=['method'],inplace=True)

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber                 Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final        Gujarat Titans
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2      Rajasthan Royals
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator  Lucknow Super Giants
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1        Gujarat Titans
# 4  1304116     Mumbai  2022-05-22   2022           70          Punjab Kings
#
#                   Team2                             Venue  \
# 0        Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 1      Rajasthan Royals  Narendra Modi Stadium, Ahmedabad
# 2  Lucknow Super Giants             Eden Gardens, Kolkata
# 3        Gujarat Titans             Eden Gardens, Kolkata
# 4          Punjab Kings          Wankhede Stadium, Mumbai
#
#              TossWinner TossDecision SuperOver                  WinningTeam  \
# 0      Rajasthan Royals          bat         N               Gujarat Titans
# ...

# %% [markdown]
# > data has been cleaned for further processing

# %%
import pandas as pd

# %%
dfb=pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
dfb.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
dfb.shape
# Out:
# (225954, 17)

# %%
dfb.info
# Out:
# <bound method DataFrame.info of              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
# ...

# %%
# checking duplicate

dfb.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# there are no duplicate value

# %%
## null 
dfb.isnull().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
dfb.drop(columns=['extras_run','player_out','kind','fielders_involved'])
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  total_run  non_boundary  \
# ...

# %%
dfb.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
dfb.rename(columns={'innings':'Innings','overs':'Overs','ballnumber':'Ballnumber','batter':'Batter', 'bowler':'Bowler',
       'non-striker':'Non-striker', 'batsman_run':'Batsman_run', 'extras_run':'Extra_run', 'total_run':'Total_run', 'non_boundary':'Non_boundary',
       'isWicketDelivery':'IsWicketDelivery'},inplace=True)

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'extra_type', 'Batsman_run', 'Extra_run', 'Total_run',
#        'Non_boundary', 'IsWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
dfb.head()
# Out:
#         ID  Innings  Overs  Ballnumber       Batter          Bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    Non-striker extra_type  Batsman_run  Extra_run  Total_run  Non_boundary  \
# 0   JC Buttler        NaN            0          0          0             0
# 1   JC Buttler    legbyes            0          1          1             0
# 2  YBK Jaiswal        NaN            1          0          1             0
# 3   JC Buttler        NaN            0          0          0             0
# 4   JC Buttler        NaN            0          0          0             0
#
#    IsWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
##   check for null values
dfb.isnull().sum()
# Out:
# ID                        0
# Innings                   0
# Overs                     0
# Ballnumber                0
# Batter                    0
# Bowler                    0
# Non-striker               0
# extra_type           213905
# Batsman_run               0
# Extra_run                 0
# Total_run                 0
# Non_boundary              0
# IsWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
dfb.nunique()
# Out:
# ID                   950
# Innings                6
# Overs                 20
# Ballnumber            10
# Batter               605
# Bowler               472
# Non-striker          595
# extra_type             5
# Batsman_run            7
# Extra_run              7
# Total_run              8
# Non_boundary           2
# IsWicketDelivery       2
# player_out           573
# kind                  10
# fielders_involved    535
# BattingTeam           18
# dtype: int64

# %%
dfb['Innings'].value_counts()
# Out:
# Innings
# 1    116883
# 2    108910
# 3        77
# 4        72
# 5         8
# 6         4
# Name: count, dtype: int64

# %%
dfb['Ballnumber'].value_counts()
# Out:
# Ballnumber
# 1     36599
# 2     36507
# 3     36413
# 4     36322
# 5     36201
# 6     36083
# 7      6585
# 8      1055
# 9       171
# 10       18
# Name: count, dtype: int64

# %%
dfb['BattingTeam'].value_counts().sort_index()
# Out:
# BattingTeam
# Chennai Super Kings            25128
# Deccan Chargers                 9034
# Delhi Capitals                  7587
# Delhi Daredevils               18786
# Gujarat Lions                   3566
# Gujarat Titans                  1971
# Kings XI Punjab                22646
# Kochi Tuskers Kerala            1582
# Kolkata Knight Riders          26192
# Lucknow Super Giants            1840
# Mumbai Indians                 27826
# Pune Warriors                   5443
# Punjab Kings                    3388
# Rajasthan Royals               22777
# Rising Pune Supergiant          1900
# Rising Pune Supergiants         1580
# Royal Challengers Bangalore    26512
# Sunrisers Hyderabad            18196
# Name: count, dtype: int64

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'extra_type', 'Batsman_run', 'Extra_run', 'Total_run',
#        'Non_boundary', 'IsWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('King XI Punjab','punjab Kings')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace('Delhi Daredevils ','punjab Kings')

# %%
dfb['BattingTeam']=dfb['BattingTeam'].replace(' Rising Pune Supergiants','Rising Pune Supergiant')

# %%
dfb['BattingTeam'].value_counts().sort_index()
# Out:
# BattingTeam
# Chennai Super Kings            25128
# Deccan Chargers                 9034
# Delhi Capitals                  7587
# Delhi Daredevils               18786
# Gujarat Lions                   3566
# Gujarat Titans                  1971
# Kings XI Punjab                22646
# Kochi Tuskers Kerala            1582
# Kolkata Knight Riders          26192
# Lucknow Super Giants            1840
# Mumbai Indians                 27826
# Pune Warriors                   5443
# Punjab Kings                    3388
# Rajasthan Royals               22777
# Rising Pune Supergiant          1900
# Rising Pune Supergiants         1580
# Royal Challengers Bangalore    26512
# Sunrisers Hyderabad            18196
# Name: count, dtype: int64

# %%
dfb.head(10)
# Out:
#         ID  Innings  Overs  Ballnumber       Batter          Bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5  1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# 6  1312200        1      1           1   JC Buttler      Yash Dayal
# 7  1312200        1      1           2   JC Buttler      Yash Dayal
# 8  1312200        1      1           3   JC Buttler      Yash Dayal
# 9  1312200        1      1           4   JC Buttler      Yash Dayal
#
#    Non-striker extra_type  Batsman_run  Extra_run  Total_run  Non_boundary  \
# 0   JC Buttler        NaN            0          0          0             0
# ...

# %%
#
dfb['Ballnumber'].value_counts().sort_index()
# Out:
# Ballnumber
# 1     36599
# 2     36507
# 3     36413
# 4     36322
# 5     36201
# 6     36083
# 7      6585
# 8      1055
# 9       171
# 10       18
# Name: count, dtype: int64

# %%
dfb['Innings'].value_counts().sort_index()
# Out:
# Innings
# 1    116883
# 2    108910
# 3        77
# 4        72
# 5         8
# 6         4
# Name: count, dtype: int64

# %%
dfb.describe()[['Overs','Ballnumber','Extra_run','Total_run']]
# Out:
#                Overs     Ballnumber      Extra_run     Total_run
# count  225954.000000  225954.000000  225954.000000  225954.00000
# mean        9.185679       3.619750       0.066907       1.31043
# std         5.681797       1.810633       0.341470       1.60605
# min         0.000000       1.000000       0.000000       0.00000
# 25%         4.000000       2.000000       0.000000       0.00000
# 50%         9.000000       4.000000       0.000000       1.00000
# 75%        14.000000       5.000000       0.000000       1.00000
# max        19.000000      10.000000       7.000000       7.00000

# %%
dfb['Overs'].value_counts()
# Out:
# Overs
# 0     12085
# 1     11935
# 2     11803
# 3     11773
# 4     11766
# 5     11720
# 6     11671
# 7     11651
# 8     11608
# 9     11578
# 10    11507
# 11    11480
# 12    11452
# 13    11355
# 14    11259
# 15    11093
# 16    10961
# 17    10650
# 18    10001
# 19     8606
# Name: count, dtype: int64

# %%
def func(x):
    return x+1

# %%
dfb['Overs'] = dfb['Overs'].apply(lambda x : x+1)  # operation i++ => 1=i+1

# %%
dfb.describe()[['Overs','Ballnumber','Batsman_run','Extra_run','Total_run']]
# Out:
#                Overs     Ballnumber    Batsman_run      Extra_run  \
# count  225954.000000  225954.000000  225954.000000  225954.000000
# mean       10.185679       3.619750       1.243523       0.066907
# std         5.681797       1.810633       1.618166       0.341470
# min         1.000000       1.000000       0.000000       0.000000
# 25%         5.000000       2.000000       0.000000       0.000000
# 50%        10.000000       4.000000       1.000000       0.000000
# 75%        15.000000       5.000000       1.000000       0.000000
# max        20.000000      10.000000       6.000000       7.000000
#
#           Total_run
# count  225954.00000
# mean        1.31043
# std         1.60605
# min         0.00000
# 25%         0.00000
# 50%         1.00000
# 75%         1.00000
# max         7.00000

# %%
dfb['Extra_run'].value_counts()
# Out:
# Extra_run
# 0    213905
# 1     10760
# 2       499
# 4       436
# 5       275
# 3        78
# 7         1
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis
# Now we will analyze our IPL dataset containing information about macthes, venue and scoring of IPL 15 seasons 2008 to 2022.

# %% [markdown]
# ##### what are the *total* teams played from 2008 to 2022 ?

# %%
(df.shape)
dfb.shape
# Out:
# (225954, 17)

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df['Teams1'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Teams1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[335], line 1
# ----> 1 df['Teams1'].value_counts()
#
# ...

# %%
teamsdf.rename(columns={'Team1':'Teams'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[375], line 1
# ----> 1 teamsdf.rename(columns={'Team1':'Teams'},inplace=True)
#
# NameError: name 'teamsdf' is not defined

# %%
len(teamsdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[382], line 1
# ----> 1 len(teamsdf)
#
# NameError: name 'teamsdf' is not defined

# %%
type(teamsdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[383], line 1
# ----> 1 type(teamsdf)
#
# NameError: name 'teamsdf' is not defined

# %%
teamsdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[384], line 1
# ----> 1 teamsdf
#
# NameError: name 'teamsdf' is not defined

# %%
teamsdf = pd.DataFrame(df['Team1'].value_counts().index,columns=['Teams'])

# %% [markdown]
# There are total 15 teams and teamdf you can see the list of team

# %% [markdown]
# Total Macthes played by each Team?

# %%
df['Team1']
# Out:
# 0                   Gujarat Titans
# 1                 Rajasthan Royals
# 2             Lucknow Super Giants
# 3                   Gujarat Titans
# 4                     Punjab Kings
#                   ...
# 945                Deccan Chargers
# 946    Royal Challengers Bangalore
# 947               Rajasthan Royals
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Name: Team1, Length: 950, dtype: object

# %%
df['Team2']
# Out:
# 0                   Gujarat Titans
# 1                 Rajasthan Royals
# 2             Lucknow Super Giants
# 3                   Gujarat Titans
# 4                     Punjab Kings
#                   ...
# 945                Deccan Chargers
# 946    Royal Challengers Bangalore
# 947               Rajasthan Royals
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Name: Team2, Length: 950, dtype: object

# %%
pd.concat([df['Team2'],df['Team2']]).value_counts()
# Out:
# Team2
# Mumbai Indians                 238
# Kolkata Knight Riders          236
# Delhi Capitals                 220
# Rajasthan Royals               206
# Royal Challengers Bangalore    200
# Kings XI Punjab                196
# Chennai Super Kings            194
# Sunrisers Hyderabad            166
# Deccan Chargers                 72
# Pune Warriors                   46
# Rising Pune Supergiant          32
# Gujarat Lions                   28
# Punjab Kings                    20
# Gujarat Titans                  18
# Lucknow Super Giants            14
# Kochi Tuskers Kerala            14
# Name: count, dtype: int64

# %%
teams_matches = pd.concat([df['Team1'],df['Team2']]).value_counts()
teams_matches = pd.DataFrame(teams_matches).reset_index()
teams_matches.rename(columns={'index':'Teams',0:'Total_Matches'},inplace=True)

# %% [markdown]
# # visualization

# %% [markdown]
# ## Matplotlib

# %%
def get_color(name, number):
    pal = list(sns.color_palette(palette=name,n_colors=number).as_hex())
    return pal

# %%
pal_vi = get_color('viridis_r', len(df))
pal_vi
# Out:
# ['#fde725',
#  '#fde725',
#  '#fde725',
#  '#fbe723',
#  '#fbe723',
#  '#fbe723',
#  '#fbe723',
#  '#f8e621',
#  '#f8e621',
#  '#f8e621',
#  '#f8e621',
#  '#f6e620',
#  '#f6e620',
#  '#f6e620',
#  '#f4e61e',
#  '#f4e61e',
#  '#f4e61e',
#  '#f4e61e',
#  '#f1e51d',
#  '#f1e51d',
#  '#f1e51d',
#  '#f1e51d',
#  '#efe51c',
#  '#efe51c',
#  '#efe51c',
#  '#efe51c',
#  '#ece51b',
#  '#ece51b',
#  '#ece51b',
#  '#eae51a',
#  '#eae51a',
#  '#eae51a',
#  '#eae51a',
#  '#e7e419',
#  '#e7e419',
#  '#e7e419',
#  '#e7e419',
#  '#e5e419',
#  '#e5e419',
#  '#e5e419',
#  '#e2e418',
#  '#e2e418',
#  '#e2e418',
#  '#e2e418',
#  '#dfe318',
#  '#dfe318',
#  '#dfe318',
#  '#dfe318',
#  '#dde318',
#  '#dde318',
#  '#dde318',
#  '#dde318',
#  '#dae319',
#  '#dae319',
#  '#dae319',
#  '#d8e219',
#  '#d8e219',
#  '#d8e219',
#  '#d8e219',
#  '#d5e21a',
#  '#d5e21a',
#  '#d5e21a',
#  '#d5e21a',
#  '#d2e21b',
#  '#d2e21b',
#  '#d2e21b',
#  '#d0e11c',
#  '#d0e11c',
#  '#d0e11c',
#  '#d0e11c',
#  '#cde11d',
# ...

# %%
teams_matches.columns
# Out:
# Index(['Teams', 'count'], dtype='object')

# %%
teams_matches.rename(columns={"count":'Total_matches'},inplace=True)

# %%
teams_matches
# Out:
#                           Teams  Total_matches
# 0                Mumbai Indians            238
# 1         Kolkata Knight Riders            236
# 2                Delhi Capitals            220
# 3              Rajasthan Royals            206
# 4   Royal Challengers Bangalore            200
# 5               Kings XI Punjab            196
# 6           Chennai Super Kings            194
# 7           Sunrisers Hyderabad            166
# 8               Deccan Chargers             72
# 9                 Pune Warriors             46
# 10       Rising Pune Supergiant             32
# 11                Gujarat Lions             28
# 12                 Punjab Kings             20
# 13               Gujarat Titans             18
# 14         Lucknow Super Giants             14
# 15         Kochi Tuskers Kerala             14

# %%
teams_matches.head(10)
# Out:
#                          Teams  Total_matches
# 0               Mumbai Indians            238
# 1        Kolkata Knight Riders            236
# 2               Delhi Capitals            220
# 3             Rajasthan Royals            206
# 4  Royal Challengers Bangalore            200
# 5              Kings XI Punjab            196
# 6          Chennai Super Kings            194
# 7          Sunrisers Hyderabad            166
# 8              Deccan Chargers             72
# 9                Pune Warriors             46

# %%
# Set figure size
plt.figure(figsize=(30, 10))

# Create bar plot
teams_matches = teams_matches.head(10)
bars = plt.bar(
    teams_matches['Teams'],
    teams_matches['Total_matches'],
    color=pal_vi[:len(teams_matches)]  # Use your color palette
)


plt.xlabel('Teams')
plt.ylabel('Total matches')
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{height}',
        ha='center',
        va='bottom',
        fontsize=10
    )

# Customize plot appearance
plt.xlabel('Teams')
plt.ylabel('Total matches')
plt.xticks(rotation=45)
plt.gca().set_facecolor('white')   # Plot background
plt.gcf().set_facecolor('white')   # Figure background

# Remove top and right spines for a cleaner look
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
team_mapping = {
    'Mumbai Indians': 'MI',
    'Royal Challengers Bangalore': 'RCB',
    'Delhi Capitals': 'DC',
    'Kolkata Knight Riders': 'KKR',
    'Punjab Kings': 'PBKS',
    'Chennai Super Kings': 'CSK',
    'Rajasthan Royals': 'RR',
    'Sunrisers Hyderabad': 'SRH',
    'Deccan Chargers': 'DCG',
    'Pune Warriors': 'PW',
    'Rising Pune Supergiant': 'RPS',
    'Gujarat Lions': 'GL',
    'Gujarat Titans': 'GT',
    'Lucknow Super Giants': 'LSG',
    'Kochi Tuskers Kerala': 'KTK'
}

teams_matches.replace(team_mapping, inplace=True)

# %%
teams_matches.columns
# Out:
# Index(['Teams', 'Total_matches'], dtype='object')

# %%
sns.set(rc={'figure.figsize':(20,10)})

# %%
teams_matches.head(10)
# Out:
#              Teams  Total_matches
# 0               MI            238
# 1              KKR            236
# 2               DC            220
# 3               RR            206
# 4              RCB            200
# 5  Kings XI Punjab            196
# 6              CSK            194
# 7              SRH            166
# 8              DCG             72
# 9               PW             46

# %%
teams_matches.rename(columns={"count":'Total_Matches'},inplace=True)

# %%
teams_matches.columns
# Out:
# Index(['Teams', 'Total_matches'], dtype='object')

# %%
ax = sns.barplot(teams_matches,x='Teams',y='Total_matches')
for bar in ax.containers:
    ax.bar_label(bar)
    plt.show()

# %%
# !pip install plotly --upgrade --quiet
# Out:
# Access is denied.

# %%
teams_matches
# Out:
#              Teams  Total_matches  total_wins
# 0               MI            238         131
# 1              KKR            236         121
# 2               DC            220         114
# 3               RR            206         109
# 4              RCB            200         103
# 5  Kings XI Punjab            196          96
# 6              CSK            194          88
# 7              SRH            166          75
# 8              DCG             72          29
# 9               PW             46          15

# %%
import plotly.express as px
fig = px.bar(teams_matches, x='Teams', y='Total_matches', text='Total_matches',
             color ='Teams')

fig.update_traces(texttemplate='%{text:.3s}', textposition='outside')
fig.update_layout({'plot_bgcolor': 'white',
                   'paper_bgcolor': 'white'})

fig.update_layout(width=1100, height=500,
                  margin = dict(t=15, l=15, r=15, b=15))
fig.show()

# %% [markdown]
# By above analysis we can see that number of matches played by Mumbai indians, Royal Challengers Bangalore, Delhi Capitals, Kolkata Knight Riders, Punjab Kings, Chennai Super Kings is high. On the other hand, Punjab Kings, Kochi Tuskers Kerala, Pune Warriors, Gujarat Lions, Rising Pune Supergiant are the defunct team by BCCI.

# %% [markdown]
# ## Winning Ratio Analysis

# %%
teams_matches
# Out:
#              Teams  Total_matches
# 0               MI            238
# 1              KKR            236
# 2               DC            220
# 3               RR            206
# 4              RCB            200
# 5  Kings XI Punjab            196
# 6              CSK            194
# 7              SRH            166
# 8              DCG             72
# 9               PW             46

# %%
win_df = teams_matches
win_df['total_wins']=df['WinningTeam'].value_counts().reset_index()['count']
win_df['win_ratio']= round((win_df['total_wins']/win_df['Total_matches']),2)*100
win_df
# Out:
#              Teams  Total_matches  total_wins  win_ratio
# 0               MI            238         131       55.0
# 1              KKR            236         121       51.0
# 2               DC            220         114       52.0
# 3               RR            206         109       53.0
# 4              RCB            200         103       52.0
# 5  Kings XI Punjab            196          96       49.0
# 6              CSK            194          88       45.0
# 7              SRH            166          75       45.0
# 8              DCG             72          29       40.0
# 9               PW             46          15       33.0

# %%
win_df = teams_matches
win_df['total_wins']=df['WinningTeam'].value_counts().reset_index()['count']
win_df['win_ratio']= round((win_df['total_wins']/win_df['Total_matches']),2)*100
win_df
# Out:
#              Teams  Total_matches  total_wins  win_ratio
# 0               MI            238         131       55.0
# 1              KKR            236         121       51.0
# 2               DC            220         114       52.0
# 3               RR            206         109       53.0
# 4              RCB            200         103       52.0
# 5  Kings XI Punjab            196          96       49.0
# 6              CSK            194          88       45.0
# 7              SRH            166          75       45.0
# 8              DCG             72          29       40.0
# 9               PW             46          15       33.0

# %%
plt.figure(figsize=(15,6.5))
sns.set_style('darkgrid')
wi = sns.barplot(data=win_df, x='win_ratio', y='Teams', ci=False, palette='viridis_r')
wi.set_xticklabels(win_df['win_ratio'], rotation=55, fontdict={'fontsize':10})
plt.show()

# %%
plt.figure(figsize=(15,6.5))
sns.set_style('darkgrid')
wi = sns.barplot(data=win_df, x='win_ratio', y='Teams', ci=False)
wi.set_xticklabels(win_df['win_ratio'].sort_values(), rotation=90, fontdict={'fontsize':10})
plt.show()

# %% [markdown]
# we can see that Gujrat Titans has best winning percentage but Gujrat Titans has low number of matches played. So, overall Mumbai Indians has good winning percentage.

# %%
player_of_macth_df = df['Player_of_Match'].value_counts().reset_index()
player_of_macth_df.rename(columns={'index':'Player_of_Match_df','Player_of_Match_df':'Count'},inplace=True)
top_10_Player_of_match = player_of_macth_df.head(10)

# %%
plt.figure(figsize=(9,4))
plt.plot(top_10_Player_of_match['count'],top_10_Player_of_match['Player_of_Match'],'o-g')

plt.xlabel('count')
plt.ylabel('Player of Match')
plt.title('Top 10 Player of Match')
plt.show()

# %% [markdown]
# Above analysis show that, with 25 man of the match trophies, **AB de Villiers** has most man of the match in IPL. While **CH Gayle** is in second number who has most man of the match in IPL.

# %% [markdown]
# ## Top 10 IPL hosted cities
# We will analyze the top cities that hosted IPL most time.

# %%
df['City'].value_counts().reset_index()
# Out:
#               City  count
# 0           Mumbai    159
# 1          Kolkata     79
# 2            Delhi     78
# 3          Chennai     67
# 4        Bangalore     65
# 5        Hyderabad     64
# 6       Chandigarh     56
# 7             Pune     51
# 8           Jaipur     47
# 9        Abu Dhabi     37
# 10         Sharjah     28
# 11       Ahmedabad     19
# 12       Bengaluru     15
# 13          Durban     15
# 14   Visakhapatnam     13
# 15           Dubai     13
# 16       Centurion     12
# 17          Rajkot     10
# 18     Navi Mumbai      9
# 19          Indore      9
# 20      Dharamsala      9
# 21    Johannesburg      8
# 22  Port Elizabeth      7
# 23         Cuttack      7
# 24          Ranchi      7
# 25       Cape Town      7
# 26          Raipur      6
# 27           Kochi      5
# 28          Kanpur      4
# 29          Nagpur      3
# 30       Kimberley      3
# 31     East London      3
# 32    Bloemfontein      2

# %%
player_of_macth_df = df['Player_of_Match'].value_counts().reset_index()
player_of_macth_df.rename(columns={'index':'Player_of_Match_df','Player_of_Match_df':'Count'},inplace=True)
top_10_Player_of_match = player_of_macth_df.head(10)

# %%
citraw = df['City'].value_counts().reset_index()

# %%
citraw = df['City'].value_counts().reset_index()
citraw.set_axis(['City','Hosted_Number'],axis = 'columns')
top10_city_host = citraw.head(10)
top10_city_host
# Out:
#          City  count
# 0      Mumbai    159
# 1     Kolkata     79
# 2       Delhi     78
# 3     Chennai     67
# 4   Bangalore     65
# 5   Hyderabad     64
# 6  Chandigarh     56
# 7        Pune     51
# 8      Jaipur     47
# 9   Abu Dhabi     37

# %%
# Count Player of the Match awards
player_of_match_df = df['Player_of_Match'].value_counts().reset_index()

# Rename columns
player_of_match_df.columns = ['Player_of_Match', 'Count']

# Get top 10 players
top_10_Player_of_match = player_of_match_df.head(10)

# Display
print(top_10_Player_of_match)
# Out:
#   Player_of_Match  Count
# 0  AB de Villiers     25
# 1        CH Gayle     22
# 2       RG Sharma     18
# 3       DA Warner     18
# 4        MS Dhoni     17
# 5       SR Watson     16
# 6       YK Pathan     16
# 7      KA Pollard     14
# 8        SK Raina     14
# 9         V Kohli     14

# %%
plt.figure(figsize=(16,8))
palette_color = sns.color_palette("ch:s=.25,rot=-.25")
sns.barplot(x='count', y='City',palette = palette_color, data=top10_city_host);
plt.title('Top 10 IPL hosted cities');
plt.show()

# %%
df["Season"]=pd.DatetimeIndex(df["Date"]).year
matches_in_season=df.groupby(['Season'])['ID'].count().reset_index().rename(columns={'ID':'matches'})
matches_in_season
# Out:
#     Season  matches
# 0     2008       58
# 1     2009       57
# 2     2010       60
# 3     2011       73
# 4     2012       74
# 5     2013       76
# 6     2014       60
# 7     2015       59
# 8     2016       60
# 9     2017       59
# 10    2018       60
# 11    2019       60
# 12    2020       60
# 13    2021       60
# 14    2022       74

# %%
plt.figure(figsize=(12,5))

sns.barplot(x='Season', y='matches', data=matches_in_season);
plt.title('No of total matches per season');
plt.show()

# %%
import pandas as pd

# %%
df["Season"]=pd.DatetimeIndex(df["Date"]).year
matches_in_season=df.groupby(['Season'])['ID'].count().reset_index().rename(columns={'ID':'matches'})
matches_in_season
# Out:
#     Season  matches
# 0     2008       58
# 1     2009       57
# 2     2010       60
# 3     2011       73
# 4     2012       74
# 5     2013       76
# 6     2014       60
# 7     2015       59
# 8     2016       60
# 9     2017       59
# 10    2018       60
# 11    2019       60
# 12    2020       60
# 13    2021       60
# 14    2022       74

# %% [markdown]
# most Time Toss Winning Teams

# %%
df['TossWinner'].value_counts().reset_index()
# Out:
#                      TossWinner  count
# 0                Mumbai Indians    123
# 1         Kolkata Knight Riders    114
# 2           Chennai Super Kings    109
# 3   Royal Challengers Bangalore    105
# 4              Rajasthan Royals     99
# 5               Kings XI Punjab     85
# 6              Delhi Daredevils     80
# 7           Sunrisers Hyderabad     74
# 8               Deccan Chargers     43
# 9                Delhi Capitals     36
# 10                Pune Warriors     20
# 11                Gujarat Lions     15
# 12               Gujarat Titans     10
# 13                 Punjab Kings      9
# 14         Kochi Tuskers Kerala      8
# 15         Lucknow Super Giants      7
# 16      Rising Pune Supergiants      7
# 17       Rising Pune Supergiant      6

# %%
most_toss_winner = df['TossWinner'].value_counts().reset_index()
most_toss_winner.rename(columns={'TossWinner':'TossWinner','count':'count'} ,inplace = True)
most_toss_winner
# Out:
#                      TossWinner  count
# 0                Mumbai Indians    123
# 1         Kolkata Knight Riders    114
# 2           Chennai Super Kings    109
# 3   Royal Challengers Bangalore    105
# 4              Rajasthan Royals     99
# 5               Kings XI Punjab     85
# 6              Delhi Daredevils     80
# 7           Sunrisers Hyderabad     74
# 8               Deccan Chargers     43
# 9                Delhi Capitals     36
# 10                Pune Warriors     20
# 11                Gujarat Lions     15
# 12               Gujarat Titans     10
# 13                 Punjab Kings      9
# 14         Kochi Tuskers Kerala      8
# 15         Lucknow Super Giants      7
# 16      Rising Pune Supergiants      7
# 17       Rising Pune Supergiant      6

# %%
plt.figure(figsize=(16,6))
color_palette = sns.color_palette("Spectral")
sns.countplot(x='Season', hue='TossDecision', data=df,palette=color_palette,saturation=1)
plt.title('Toss Decision in each Season of IPL');
plt.show()

# %% [markdown]
# In 2016, 2017, 2018, and 2019 most of the teams were field first after winning the toss. But the data show that, in 2020 teams went for bat first after winning toss because in 2020 IPL was held in Dubai, and Dubai stadium's ground and weather conditions suit for bat first. After 2020, in 2021 and 2022 teams again chose the field first after winning toss because IPL held again in INDIA.

# %% [markdown]
# Match team won gerter IPL Trophies?

# %%
f1=(df['MatchNumber']=='Final')
winning_team=df[f1]

# %%
winning_team= winning_team['WinningTeam'].value_counts().reset_index().rename(columns={'index':'Team','Winning_team':'Total Titles'})

# %%
winning_team
# Out:
#              WinningTeam  count
# 0         Mumbai Indians      5
# 1    Chennai Super Kings      4
# 2  Kolkata Knight Riders      2
# 3         Gujarat Titans      1
# 4    Sunrisers Hyderabad      1
# 5        Deccan Chargers      1
# 6       Rajasthan Royals      1

# %%
plt.figure(figsize=(6,6))
plt.pie(winning_team['count'])
plt.show()

# %%
import plotly.express as px
fig = px.pie(winning_team, values=winning_team['count'], names=winning_team['count'],
             color =winning_team['count'])
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  sort=False)
fig.update_layout(width=500, height=550)
fig.show()

# %% [markdown]
# Above chart and data show that Gujarat Titans gets most time the title of winner of IPL League.

# %% [markdown]
# ## Who is the best wicket taker bowler in IPL history?

# %%
dfb.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'Ballnumber', 'Batter', 'Bowler',
#        'Non-striker', 'extra_type', 'Batsman_run', 'Extra_run', 'Total_run',
#        'Non_boundary', 'IsWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
dfb['IsWicketDelivery'].value_counts() # 0 - No wicket ,  1 - wicket
# Out:
# IsWicketDelivery
# 0    214803
# 1     11151
# Name: count, dtype: int64

# %%
### Check the bowlers column 
wicket_takers = dfb.groupby('Bowler').sum().reset_index()

# %%
wt = wicket_takers[['Bowler','IsWicketDelivery']]

# %%
wt.rename(columns={'IsWicketDelivery':'Total_Wickets'},inplace=True)

# %%
wt = wt.sort_values(by='Total_Wickets',ascending=False).head(10).reset_index(drop=True)
wt
# Out:
#             Bowler  Total_Wickets
# 0         DJ Bravo            207
# 1       SL Malinga            188
# 2         A Mishra            175
# 3         R Ashwin            174
# 4        YS Chahal            172
# 5        SP Narine            171
# 6        PP Chawla            165
# 7          B Kumar            165
# 8        JJ Bumrah            161
# 9  Harbhajan Singh            161

# %%
ax = sns.barplot(wt,x='Bowler',y='Total_Wickets')
sns.set(rc={'figure.figsize':(1000,700)})
for bar in ax.containers:
    ax.bar_label(bar) 
    # Set figure size before plotting
sns.set(rc={'figure.figsize': (20, 8)})

ax = sns.barplot(data=wt, x='Bowler', y='Total_Wickets')

# Add labels on bars
for bar in ax.containers:
    ax.bar_label(bar)

# Rotate x-axis labels vertically
plt.xticks(rotation=90)
# Increase font size and make tick labels bold
plt.setp(ax.get_xticklabels(), fontsize=20, fontweight='bold')
plt.setp(ax.get_yticklabels(), fontsize=24, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(wt['Bowler'], wt['Total_Wickets'], marker='o', c='c', ls='-.', lw=2, ms=10, mew=2, mec='navy')

plt.xlabel('Bowler')
plt.ylabel('Wickets taken')

plt.title('Top 10 wickets tackers');
plt.show()

# %% [markdown]
# By above plot and data we can see that **DJ Bravo** is the most wicket taker bowler in IPL history.

# %% [markdown]
# ## What is Toss Decision Ratio in IPL?

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
###'TossWinner', 'TossDecision'
df['TossWinner'].value_counts()
# Out:
# TossWinner
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Gujarat Titans                  10
# Punjab Kings                     9
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
d1 =  df['TossDecision'].value_counts()

# %%
d1 = d1.reset_index().rename(columns={'index':'TossDecision','TossDecision':'count'})

# %%
d1['Ratio'] = d1['count'].apply(lambda x : round(x/total,2)*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %%
d1
# Out:
# TossDecision
# field    599
# bat      351
# Name: count, dtype: int64

# %%
d1 = d1.reset_index().rename(columns={'count':'TossDecision','TossDecision':'count'})

# %%
d1['count'].dtype
# Out:
# dtype('O')

# %%
d1 = d1.reset_index().rename(columns={'index':'TossDecision','TossDecision':'count'})

# %%
d1['Ratio'] = d1['count'].apply(lambda x : round(x/total,2)*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %%
d1
# Out:
#    count  TossDecision
# 0  field           599
# 1    bat           351

# %%
fig = px.pie(  d1, values=d1['Ratio'], names=d1['TossDecision'])
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  sort=False)
fig.update_layout(width=500, height=550)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:228, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 'Ratio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[366], line 1
# ----> 1 fig = px.pie(  d1, values=d1['Ratio'], names=d1['TossDecision'])
#       2 fig.update_traces(textposition='inside',
#       3                   textinfo='percent+label',
# ...

# %% [markdown]
# In IPL we can see that most of the teams chose to field first after winning toss.

# %% [markdown]
# ## Is win depend on winning toss?

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.TossWinner
# Out:
# 0                 Rajasthan Royals
# 1                 Rajasthan Royals
# 2             Lucknow Super Giants
# 3                   Gujarat Titans
# 4              Sunrisers Hyderabad
#                   ...
# 945                Deccan Chargers
# 946                 Mumbai Indians
# 947               Rajasthan Royals
# 948            Chennai Super Kings
# 949    Royal Challengers Bangalore
# Name: TossWinner, Length: 950, dtype: object

# %%
total=(df.TossWinner==df.WinningTeam).value_counts().sum()

# %%
total
# Out:
# np.int64(950)

# %%
toss_vs_matchwin = (df.TossWinner==df.WinningTeam).value_counts()
toss_vs_matchwin
# Out:
# False    499
# True     451
# Name: count, dtype: int64

# %%
tm=toss_vs_matchwin.reset_index().rename(columns={'index':'isTosswinner','0':'count'})

# %%
tm['Percentage']=round((tm['count']/total)*100,2)
tm
# Out:
#    isTosswinner  count  Percentage
# 0         False    499       52.53
# 1          True    451       47.47

# %%
import plotly.express as px

# %%
fig = px.pie(tm, values=tm['Percentage'], names=['Toss Lost','Toss Won'])
fig.update_traces(textposition='inside',
                  textinfo='percent+label',
                  sort=False)
fig.update_layout(width=500, height=550)
fig.show()

# %% [markdown]
# ## Which batsmen have most runs in IPL history?

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'Player_of_Match', 'Team1Players', 'Team2Players',
#        'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
highest_run_batsmans=dfb.groupby('Batter').sum().reset_index()
highest_run_batsmans = highest_run_batsmans.sort_values(by='Batsman_run',ascending=False).head(10)
highest_run_batsmans[['Batter','Batsman_run']]
# Out:
#              Batter  Batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %%
plt.figure(figsize=(12,5))

plt.pie(highest_run_batsmans['Batsman_run'],labels=highest_run_batsmans['Batter'],autopct='%.0f%%')
plt.title('BATSMEN WITH MOST RUNS IN IPL HISTORY')
plt.show()

# %% [markdown]
# By analyzing data we can see that **V Kholi** has maximum runs in the history of IPL followed by **S Dhawan**, **DA Warner** and **RG Sharma**.

# %% [markdown]
# ### Inferences and Conclusion (Story Telling)
# - We analyzing the IPL dataset by different techniques and by plotting charts. We get the information that Mumbai Indians play most matches than other teams and Mumbai Indians winning ratio is also good. So, we get that Mumbai Indian is most successful team of IPL. We also get that Virat Kholi is the most valuable player of IPL beacause he become most time player of match and he is also a batsmen of most runs in IPL history. And DJ Bravo is most wicket taker bowler in IPL history. We also analyze that most toss winning teams chose to field first and most of the toss winning teams winned up 47% of matches but remaining 53% owned one who lost but even if the team has good player they can make the team to win matches reagardless of toss factor . So, we can say that winnig toss depend on match win.
#
# - In this analysis, we also get that in which season most matches played and which city hosted most matches of IPL. We also fin that which team won most time the title of winning IPL and which is the most toss winning team in IPL.
#
# I wish you all will like my project. This Exploratory Data Analysis can be improve and can gives more information by plotting and visulizing different charts.
